# %% [markdown]
# # Importin' da Jauntiez

# %%
import os
import numpy as np
from IPython.display import HTML

from HMM import unsupervised_HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    OGparse_observations,
    dublyparz,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)

# %% [markdown]
# ## Visualization of the dataset

# %%
text = open(os.path.join(os.getcwd(), 'data/shakespeare.txt')).read()
text2 = open(os.path.join(os.getcwd(), 'data/Spenser.txt')).read()
wordcloud = text_to_wordcloud(text, title="Shakespeare's Barz")
wordcloud2 = text_to_wordcloud(text2, title="Spenser's Barz")

# %% [markdown]
# ## Training MarkyMark

# %% [markdown]
# We trained MarkyMark on our dataset with 10 hidden states over 100 iterations

# %%
obs, obs_map = dublyparz(text, text2)
obs2, obs_map2 = OGparse_observations(text)
MarkyMark = unsupervised_HMM(obs, 10, 100)
OnlyShakez = unsupervised_HMM(obs2, 10, 100)
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100

# %% [markdown]
# ## Visualization of the sparsities of A and O

# %%
visualize_sparsities(MarkyMark, O_max_cols=50)
print("Only Shakespeare:")
visualize_sparsities(OnlyShakez, O_max_cols=50)
# Out:
# Only Shakespeare:

# %% [markdown]
# ## Visualizing the wordclouds of each state

# %%
wordclouds = states_to_wordclouds(MarkyMark, obs_map)
print("Only Shakespeare Data:")
wordclouds2 = states_to_wordclouds(OnlyShakez, obs_map2)
# Out:
# Only Shakespeare Data:

# %% [markdown]
# ## Visualizing the process of MarkyMark generating a Poem

# %% [markdown]
# The visualization below shows how MarkyMark generates a poem. Each state is shown as a wordcloud on the plot, and transition probabilities between the states are shown as arrows. The darker an arrow, the higher the transition probability.

# %%
#anim = animate_emission(MarkyMark, obs_map, M=8)
#HTML(anim.to_html5_video())
#print("Only Shakespeare Data:")
anim2 = animate_emission(OnlyShakez, obs_map2, M=8)
HTML(anim2.to_html5_video())
# Out:
# Animating...
# <video width="864" height="864" controls autoplay loop>
#   <source type="video/mp4" src="...
